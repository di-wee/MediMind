# %%
import pytesseract as pt
import glob
from IPython.display import Image, display

print(r'Enter path of Image e.g G:\images\1.jpg')
path = input()

display(Image(filename=path))
print(pt.image_to_string(path))
# Out:
# Enter path of Image e.g G:\images\1.jpg
# The Medical Centre Clinic (Hong Leong)
# 16, Raffles Quay, #14-05, Hong Leong Bldg, S 048581 Tel: 62207585
# Mac Lozenges - Qty: 24.00 tab/s 41 Jun 2025
#
# Suck 1 tab/s 3 times a day
# Take as Instructed
#
# XXXXX601W JIANG YU

# %%
aa = pt.image_to_string(path)

# %%
aa
# Out:
# 'The Medical Centre Clinic (Hong Leong)\n16, Raffles Quay, #14-05, Hong Leong Bldg, S 048581 Tel: 62207585\nMac Lozenges - Qty: 24.00 tab/s 41 Jun 2025\n\nSuck 1 tab/s 3 times a day\nTake as Instructed\n\nXXXXX601W JIANG YU\n'

# %%
# !pip install pytesseract

# %%
# !pip install glob
# Out:
# ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob

# %%
import pytesseract as pt
from PIL import Image as PILImage
from IPython.display import Image, display  # Optional, only for Jupyter Notebook

# OPTIONAL: Set Tesseract path if it's not in your system PATH
# pt.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# === SET YOUR IMAGE PATH HERE ===
# Replace 'your_image.jpg' with the actual image file name
image_path = r"C:\Users\prisc\OneDrive\Desktop\Github\MediMind\ml\imageForTestingTesseract\9.jpg"

# OPTIONAL: Display the image (only if you're using Jupyter)
display(Image(filename=image_path))

# Load and run OCR
img = PILImage.open(image_path)
text = pt.image_to_string(img)

# Print result
print("=== OCR Output ===")
print(text)
# Out:
# === OCR Output ===
# CODEINE 30mg tablet STABIS
# TAKE 1 TABIS at bedtime
#
# May cause drowsiness
# ree eoucn

# %%
import pytesseract as pt
from PIL import Image as PILImage
from IPython.display import Image, display  # Optional, only for Jupyter Notebook

# OPTIONAL: Set Tesseract path if it's not in your system PATH
# pt.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# === SET YOUR IMAGE PATH HERE ===
# Replace 'your_image.jpg' with the actual image file name
image_path = r"C:\Users\prisc\OneDrive\Desktop\Github\MediMind\ml\imageForTestingTesseract\012.jpg"

# OPTIONAL: Display the image (only if you're using Jupyter)
display(Image(filename=image_path))

# Load and run OCR
img = PILImage.open(image_path)
text = pt.image_to_string(img)

# Print result
print("=== OCR Output ===")
print(text)
# Out:
# === OCR Output ===
# Se ae
#
# Sh
#
# THE MEDICAL CLINIC PTE LTD
# » OCBS ¢,
#
# 33 Chula Street 404 B's East, Singapore 49516 |
# Tel: 65355153. @arail.com |
#
# PIRITON [(Chlorpheniram
# 10 TABS
#
# Take 1 Taps at bedtime
#
# for allergy,runny Nose at night
# (ORowsy)
#
# SUO ZHIYONG (Exxxx6814) NN
#
# ine Maleate] 4mg Tanig
#
# HE Menicai CTIAW im,

# %%
import pytesseract as pt
from PIL import Image as PILImage
from IPython.display import Image, display  # Optional, only for Jupyter Notebook

# OPTIONAL: Set Tesseract path if it's not in your system PATH
# pt.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# === SET YOUR IMAGE PATH HERE ===
# Replace 'your_image.jpg' with the actual image file name
image_path = r"C:\Users\prisc\OneDrive\Desktop\Github\MediMind\ml\imageForTestingTesseract\079.png"

# OPTIONAL: Display the image (only if you're using Jupyter)
display(Image(filename=image_path))

# Load and run OCR
img = PILImage.open(image_path)
text = pt.image_to_string(img)

# Print result
print("=== OCR Output ===")
print(text)
# Out:
# === OCR Output ===
# a
# FAITH Clinic (Bedok)
#
# Blk 746 Bedok Reservoir Road #01-3013
# inyapore(470746) Tel: 6702 0820
#
# se rl _lCdra
#
# Jledicine ;ALLERTEC 10MG (RUNNY NOSE /1TCH/
#
# 1 TAB IN THE MORNING (5 TAB)
# yw. faithmedical sg,
